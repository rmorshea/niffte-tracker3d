(29, 15), (30, 20), (31, 24), (32, 26), (33, 25), (34, 21), (35, 16), (36, 12), (37, 8), (38, 6), (39, 5), (40, 3)], '3751': [(17, 39), (18, 42), (19, 38), (20, 29), (21, 20), (22, 12)], '3750': [(20, 19), (21, 27), (22, 37), (23, 43), (24, 46), (25, 43)], '3214': [(17, 8), (18, 7), (19, 5), (20, 4), (21, 3), (22, 2), (23, 2), (24, 2), (25, 2), (26, 4), (27, 4)], '3215': [(21, 2), (25, 20), (26, 14), (27, 9), (28, 6), (29, 5), (30, 5), (31, 5), (32, 5), (33, 4)], '3216': [(27, 6), (28, 5), (29, 4), (30, 3), (31, 3), (32, 3), (33, 3), (34, 2), (35, 3), (36, 3), (37, 4), (38, 4), (39, 5), (40, 5)], '3217': [(31, 1), (39, 4), (40, 3), (41, 3), (42, 3), (43, 3), (44, 4), (45, 5), (46, 5)], '3212': [(18, 9), (19, 11)], '3213': [(15, 55), (16, 56), (17, 49), (18, 39), (19, 27), (20, 18), (21, 13), (22, 9), (29, 2)], '3524': [(41, 7), (42, 11)], '3525': [(40, 17)], '3522': [(43, 22), (44, 31)], '3523': [(42, 24), (43, 33)], '3725': [(39, 18)], '3726': [(38, 28), (39, 39)], '3727': [(37, 31), (38, 39)], '3448': [(30, 5), (31, 4), (32, 4), (33, 4), (34, 4), (35, 4), (36, 5), (37, 6), (38, 5)], '3445': [(41, 4), (42, 4), (43, 4), (44, 4), (45, 4), (46, 5), (47, 5)], '3447': [(33, 8), (34, 11), (35, 13), (36, 16), (37, 17), (38, 16), (39, 14), (40, 10), (41, 7), (42, 8)], '3446': [(37, 9), (38, 10), (39, 14), (40, 16), (41, 17), (42, 16), (43, 13), (44, 10), (45, 7), (46, 6)], '3441': [(41, 18), (42, 21), (43, 24)], '3440': [(39, 14), (40, 16), (41, 17), (42, 16)], '3442': [(43, 18), (44, 20), (45, 22)], '3638': [(35, 7), (36, 6), (37, 7)], '3636': [(32, 23), (33, 29)], '3113': [(17, 10), (18, 15)], '3634': [(27, 24), (28, 31), (29, 36), (30, 33)], '3635': [(29, 7), (30, 7), (31, 8), (32, 7)], '3632': [(25, 8), (26, 9), (27, 10)], '3633': [(26, 35), (27, 40), (28, 36), (29, 29)], '3631': [(24, 33), (25, 43)], '3533': [(27, 24)], '3535': [(30, 18), (31, 27), (32, 41)], '3534': [(27 ...

# %%
fig = plt.figure(1, figsize=(10,8))
ax = fig.add_subplot(1,1,1, projection = '3d')
ax.scatter(xs,ys,zs)

# %%
XY=[(31, 6), (32, 5), (33, 5), (34, 4), (35, 4), (36, 3), (37, 3), (38, 3), (39, 3), (40, 4)]
X=[i[0] for i in XY]
Y=[i[1] for i in XY]

# %%
plt.scatter(X,Y)

# %%
from scipy.optimize import curve_fit

p0 = [1., 0., 1.]
def gaus(x,A,mu,sigma,B):
    return A*np.exp(-(x-mu)**2/(2.*sigma**2))+B

count=0

for XY in padDict.values():
    x=[i[0] for i in XY]
    y=[i[1] for i in XY]
    n = len(x)
    mean = x[y.index(max(y))]
    try:
        popt,pcov = curve_fit(gaus,x,y,p0=[max(y),mean,1,1])
        pcov = np.sqrt(np.diag(pcov))
        if np.average(pcov)<1e8 and np.average(pcov)>500:
            plt.show()
            if not printline:
                print '-------------------------------------------'
            xfit = np.linspace(min(x),max(x),100)
            yfit = gaus(xfit,*popt)

            plt.scatter(x,y)
            plt.plot(xfit,yfit)
            plt.show()
            print '!!!bad error!!!'
            print pcov
            printline=True
            continue
        
        if np.average(pcov)<10 and np.average(pcov)>1:
            plt.show()
            if not printline:
                print '-------------------------------------------'
            xfit = np.linspace(min(x),max(x),100)
            yfit = gaus(xfit,*popt)

            plt.scatter(x,y)
            plt.plot(xfit,yfit)
            plt.show()
            print '!bad error!'
            print pcov
            printline=True
            continue
        
        
        if printline:
            print '-------------------------------------------'
        printline=False
        
        xfit = np.linspace(min(x),max(x),100)
        yfit = gaus(xfit,*popt)

        plt.scatter(x,y)
        plt.plot(xfit,yfit)
        plt.show()
        print pcov
        count+=1
    except:
        x=None

print
print count
# Out:
# -------------------------------------------
# !bad error!
# [ 1.42097174  3.11814934  1.81409257  0.27165274]
# -------------------------------------------
# [ 0.49900015  0.39649028  0.46106035  0.27449139]
# -------------------------------------------
# !bad error!
# [ 1.87071736  1.6862611   1.1469822   0.54929581]
# !bad error!
# [ 3.58599263  6.38437803  3.14073914  0.27704771]
# -------------------------------------------
# [ 0.96606534  0.06865295  0.14645416  0.99650142]
# [ 0.82902843  0.15530134  0.26461438  0.74322788]
# [ 0.56113321  0.18166245  0.39280829  0.58963642]
# -------------------------------------------
# !!!bad error!!!
# [  1.57478069e+06   8.89221960e+03   1.94130962e+04   3.53552028e-01]
# -------------------------------------------
# [ 0.91046714  0.32903285  0.31279906  0.68505243]
# -------------------------------------------
# !!!bad error!!!
# [  2.53419715e+07   2.97464742e+04   8.44152809e+04   7.74555523e-01]
# -------------------------------------------
# [ 0.67277786  0.12685321  0.17818556  0.47336206]
# [ 1.22728916  0.05824557  0.12508669  1.26301564]
# [ 0.5203709   0.08364614  0.11868043  0.37288006]
# [ 0.35836222  0.0326679   0.06004013  0.34213807]
# [ 1.34867924  0.03746091  0.10086035  1.44973752]
# -------------------------------------------
# !bad error!
# [ 4.89155744  0.07052502  0.29932615  5.10330025]
# -------------------------------------------
# [ 1.15012248  1.25235037  0.89066545  0.37050246]
# [ 1.7875084   0.53134679  0.38828248  0.56723026]
# -------------------------------------------
# !bad error!
# [ 0.98939512  1.89433614  1.49807254  0.28930927]
# -------------------------------------------
# [ 0.91101767  0.91589991  1.01231678  0.45494037]
# [ 1.4816754   0.18951291  0.17582418  1.17150307]
# [ 0.44376117  0.21648722  0.20424468  0.17587496]
# [ 0.95484224  0.1111155   0.25467561  1.0041252 ]
# [ 0.90646622  0.07664051  0.21532477  0.9794647 ]
# [ 0.  0.  0.  0.]
# [ 0.12710176  0.09789482  0.10152602  0.09810639]
# [ nan  nan  nan  nan]
# [ 0.51677649  0.26536507  0.51569081  0.5085577 ]
# [ 0.77448824  0.06920435  0.17716449  0.83223872]
# [ 0.54727241  0.27384421  0.44374174  0.50956094]
#
# 23

# %%
not True
# Out:
# False
